# %%
#beautifulsoub no need for json api
import json
import requests
import pandas as pd

# %%
space_url="https://api.sofascore.com/api/v1/unique-tournament/1900/season/34713/standings/total"

# %%
r=requestsests.get(space_url)

# %%
json_object=json.loads(r.content)

# %%
json_object
# Out:
# {'standings': [{'tournament': {'name': 'Indian Super League',
#     'slug': 'indian-super-league',
#     'category': {'name': 'India',
#      'slug': 'india',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 352,
#      'flag': 'india',
#      'alpha2': 'IN'},
#     'uniqueTournament': {'name': 'Indian Super League',
#      'slug': 'indian-super-league',
#      'category': {'name': 'India',
#       'slug': 'india',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 352,
#       'flag': 'india',
#       'alpha2': 'IN'},
#      'userCount': 18428,
#      'id': 1900},
#     'id': 38566},
#    'type': 'total',
#    'name': 'Indian Super League',
#    'descriptions': [],
# ...

# %%
json_object.__len__()
# Out:
# 1

# %%
json_object.keys()
# Out:
# dict_keys(['standings'])

# %%
json_object['standings']
# Out:
# [{'tournament': {'name': 'Indian Super League',
#    'slug': 'indian-super-league',
#    'category': {'name': 'India',
#     'slug': 'india',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 352,
#     'flag': 'india',
#     'alpha2': 'IN'},
#    'uniqueTournament': {'name': 'Indian Super League',
#     'slug': 'indian-super-league',
#     'category': {'name': 'India',
#      'slug': 'india',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 352,
#      'flag': 'india',
#      'alpha2': 'IN'},
#     'userCount': 18428,
#     'id': 1900},
#    'id': 38566},
#   'type': 'total',
#   'name': 'Indian Super League',
#   'descriptions': [],
# ...

# %%
len(json_object)
# Out:
# 1

# %%
len(json_object['standings'][0])
# Out:
# 8

# %%
(json_object['standings'][0]).keys()
# Out:
# dict_keys(['tournament', 'type', 'name', 'descriptions', 'tieBreakingRule', 'rows', 'id', 'updatedAtTimestamp'])

# %%
df=pd.json_normalize((json_object['standings'][0]['rows']))

# %%
df
# Out:
#    descriptions  position  matches  wins  losses  draws  scoresFor  \
# 0            []         1       20    12       4      4         35
# 1            []         2       20    12       4      4         28
# 2            []         3       20     8       3      9         31
# 3            []         4       20     7       3     10         31
# 4            []         5       20     6       3     11         27
# 5            []         6       20     7       7      6         21
# 6            []         7       20     5       8      7         26
# 7            []         8       20     3       6     11         17
# 8            []         9       20     3       9      8         22
# 9            []        10       20     3       9      8         23
# 10           []        11       20     2      12      6         25
#
#     scoresAgainst  points      id  ... team.nameCode team.national team.type  \
# 0              18      40  541930  ...           MCI         False         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   descriptions               11 non-null     object
#  1   position                   11 non-null     int64
#  2   matches                    11 non-null     int64
#  3   wins                       11 non-null     int64
#  4   losses                     11 non-null     int64
#  5   draws                      11 non-null     int64
#  6   scoresFor                  11 non-null     int64
#  7   scoresAgainst              11 non-null     int64
#  8   points                     11 non-null     int64
#  9   id                         11 non-null     int64
#  10  team.name                  11 non-null     object
#  11  team.slug                  11 non-null     object
#  12  team.shortName             11 non-null     object
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-ba61fffccbeb> in <module>
# ----> 1 import files
#
# ModuleNotFoundError: No module named 'files'
